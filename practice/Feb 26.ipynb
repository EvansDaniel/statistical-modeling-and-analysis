# %%
library(Stat2Data)
library(graphics)
data(Kids198)
k = Kids198
head(k)
# Out:
#   Height Weight Age Sex Race
# 1 67.8   166    210 0   1
# 2 63.0    93    144 1   0
# 3 50.1    54    119 0   0
# 4 55.7    69    130 1   0
# 5 63.2   115    157 0   0
# 6 48.8    52    102 0   0

# %%
hist(k$Weight)
# Out:
# Plot with title “Histogram of k$Weight”

# %%
data(Perch)
attach(Perch)
Perch.lm3 = lm(Weight ~ Length*Width + I(Length^2) + I(Width^2))
# Out:
# The following objects are masked from Perch (pos = 3):
#
#     Length, Obs, Weight, Width
#
# The following objects are masked from Perch (pos = 4):
#
#     Length, Obs, Weight, Width

# %%
Perch.lm2 <- lm(Weight ~ Length + Width + Length:Width)
summary(Perch.lm2)
# Out:
# Call:
# lm(formula = Weight ~ Length + Width + Length:Width)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -140.106  -12.226    1.230    8.489  181.408
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  113.9349    58.7844   1.938    0.058 .
# Length        -3.4827     3.1521  -1.105    0.274
# Width        -94.6309    22.2954  -4.244 9.06e-05 ***
# Length:Width   5.2412     0.4131  12.687  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 44.24 on 52 degrees of freedom
# Multiple R-squared:  0.9847,	Adjusted R-squared:  0.9838
# F-statistic:  1115 on 3 and 52 DF,  p-value: < 2.2e-16

# %%
anova(Perch.lm3)
# Out:
#              Df Sum Sq     Mean Sq     F value     Pr(>F)
# Length        1 6118739.40 6118739.404 3289.641284 2.723875e-47
# Width         1  110592.92  110592.919   59.458494 4.667076e-10
# I(Length^2)   1  314898.74  314898.739  169.300215 1.128013e-17
# I(Width^2)    1    5381.32    5381.320    2.893180 9.516744e-02
# Length:Width  1    3481.77    3481.770    1.871918 1.773729e-01
# Residuals    50   93000.10    1860.002          NA           NA

# %%
mean(Length)
# Out:
# [1] 29.57143

# %%
Perch.lm3 = lm(formula = Weight ~ Length * Width + I(Length^2) + I(Width^2))
summary(Perch.lm3)
# Out:
# Call:
# lm(formula = Weight ~ Length * Width + I(Length^2) + I(Width^2))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -117.175  -11.904    2.822   11.556  157.596
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  156.3486    61.4152   2.546   0.0140 *
# Length       -25.0007    14.2729  -1.752   0.0860 .
# Width         20.9772    82.5877   0.254   0.8005
# I(Length^2)    1.5719     0.7244   2.170   0.0348 *
# I(Width^2)    34.4058    18.7455   1.835   0.0724 .
# Length:Width  -9.7763     7.1455  -1.368   0.1774
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 43.13 on 50 degrees of freedom
# Multiple R-squared:  0.986,	Adjusted R-squared:  0.9846
# F-statistic: 704.6 on 5 and 50 DF,  p-value: < 2.2e-16

# %%
anova(Perch.lm2, Perch.lm3)
# Out:
#   Res.Df RSS      Df Sum of Sq F        Pr(>F)
# 1 52     101764.7 NA       NA        NA       NA
# 2 50      93000.1  2 8764.564  2.356063 0.105235

# %%
Perch.lm4 <- lm(Weight ~ Length + Width + I(Length^2) + I(Width^2))
anova(Perch.lm4, Perch.lm3)
# Out:
#   Res.Df RSS      Df Sum of Sq F        Pr(>F)
# 1 51     96481.87 NA      NA         NA        NA
# 2 50     93000.10  1 3481.77   1.871918 0.1773729
