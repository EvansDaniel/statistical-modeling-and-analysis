# %%
library(Stat2Data)
library(lattice)
data(Jurors)
head(Jurors)
# Out:
#   Period PctReport Year I2000
# 1 1      83.3      1998 0
# 2 2      83.6      1998 0
# 3 3      70.5      1998 0
# 4 4      70.7      1998 0
# 5 5      80.5      1998 0
# 6 6      81.6      1998 0

# %%
hist(Jurors$Year)
# Out:
# Plot with title “Histogram of Jurors$Year”

# %%
hist(Jurors$Period)
# Out:
# Plot with title “Histogram of Jurors$Period”

# %%
xyplot(Jurors$PctReport ~ Jurors$Period, group=Jurors$Year, type=c('r','p'), auto.key=TRUE)
print(cor(Jurors$PctReport, Jurors$Period))
# Out:
# [1] -0.4377677
# plot without title

# %%
summary(Jurors)
# Out:
#      Period       PctReport          Year          I2000
#  Min.   : 1.0   Min.   :50.70   Min.   :1998   Min.   :0.0
#  1st Qu.: 7.0   1st Qu.:65.00   1st Qu.:1998   1st Qu.:0.0
#  Median :13.5   Median :76.15   Median :1999   Median :0.5
#  Mean   :13.5   Mean   :76.32   Mean   :1999   Mean   :0.5
#  3rd Qu.:20.0   3rd Qu.:87.20   3rd Qu.:2000   3rd Qu.:1.0
#  Max.   :26.0   Max.   :97.00   Max.   :2000   Max.   :1.0

# %%
periodI2000Lm = lm(Jurors$PctReport ~ Jurors$Period + Jurors$I2000)
summary(periodI2000Lm)
# Out:
# Call:
# lm(formula = Jurors$PctReport ~ Jurors$Period + Jurors$I2000)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -16.8294  -3.3873  -0.8705   4.7642  14.1212
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)    77.0816     2.1297  36.193  < 2e-16 ***
# Jurors$Period  -0.7169     0.1241  -5.779 5.12e-07 ***
# Jurors$I2000   17.8346     1.8608   9.585 8.08e-13 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.709 on 49 degrees of freedom
# Multiple R-squared:  0.7188,	Adjusted R-squared:  0.7073
# F-statistic: 62.63 on 2 and 49 DF,  p-value: 3.166e-14

# %%
data(Kids198)
head(Kids198)
print(summary(Kids198))
# Out:
#   Height Weight Age Sex Race
# 1 67.8   166    210 0   1
# 2 63.0    93    144 1   0
# 3 50.1    54    119 0   0
# 4 55.7    69    130 1   0
# 5 63.2   115    157 0   0
# 6 48.8    52    102 0   0
#      Height          Weight         Age             Sex
#  Min.   :47.40   Min.   : 47   Min.   : 99.0   Min.   :0.0000
#  1st Qu.:56.05   1st Qu.: 77   1st Qu.:131.2   1st Qu.:0.0000
#  Median :61.00   Median :103   Median :158.0   Median :1.0000
#  Mean   :60.69   Mean   :104   Mean   :158.4   Mean   :0.5152
#  3rd Qu.:65.55   3rd Qu.:128   3rd Qu.:184.8   3rd Qu.:1.0000
#  Max.   :72.70   Max.   :198   Max.   :221.0   Max.   :1.0000
#       Race
#  Min.   :0.0000
#  1st Qu.:0.0000
#  Median :0.0000
#  Mean   :0.1212
#  3rd Qu.:0.0000
#  Max.   :1.0000

# %%
hist(Kids198$Weight)
# Out:
# Plot with title “Histogram of Kids198$Weight”

# %%
hist(Kids198$Age)
# Out:
# Plot with title “Histogram of Kids198$Age”

# %%
xyplot(Kids198$Weight ~ Kids198$Age, group=Kids198$Sex, auto.key=TRUE, type=c('p','r'))
# Out:
# plot without title

# %%
weightAgeSexLm = lm(Kids198$Weight ~ Kids198$Age + Kids198$Sex)
summary(weightAgeSexLm)
# Out:
# Call:
# lm(formula = Kids198$Weight ~ Kids198$Age + Kids198$Sex)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -47.311 -12.577  -1.933  10.024  58.727
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -8.40655    6.98870  -1.203     0.23
# Kids198$Age   0.75138    0.04164  18.043  < 2e-16 ***
# Kids198$Sex -12.78433    2.80963  -4.550 9.41e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 19.71 on 195 degrees of freedom
# Multiple R-squared:  0.648,	Adjusted R-squared:  0.6444
# F-statistic: 179.5 on 2 and 195 DF,  p-value: < 2.2e-16
