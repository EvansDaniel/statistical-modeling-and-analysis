# %%
library(lattice)
library(Stat2Data)
data(PorscheJaguar)

# %%
pj = PorscheJaguar
head(pj)
# Out:
#   Car     Price Age Mileage Porsche
# 1 Porsche 69.4  3   21.5    1
# 2 Porsche 56.9  3   43.0    1
# 3 Porsche 49.9  2   19.9    1
# 4 Porsche 47.4  4   36.0    1
# 5 Porsche 42.9  4   44.0    1
# 6 Porsche 36.9  6   49.8    1

# %%
xyplot(pj$Price ~ pj$Mileage, group=pj$Porsche, auto.key=TRUE, type=c('p','r'))
# Out:
# plot without title

# %%
porscheLm = lm(pj$Price ~ pj$Mileage + pj$Porsche)
summary(porscheLm)
# Out:
# Call:
# lm(formula = pj$Price ~ pj$Mileage + pj$Porsche)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -23.8420  -5.6835  -0.5041   5.4209  19.3490
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 53.60555    2.56951  20.862  < 2e-16 ***
# pj$Mileage  -0.60298    0.05427 -11.111 6.89e-16 ***
# pj$Porsche  17.95833    2.36951   7.579 3.45e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.174 on 57 degrees of freedom
# Multiple R-squared:  0.7644,	Adjusted R-squared:  0.7562
# F-statistic: 92.48 on 2 and 57 DF,  p-value: < 2.2e-16

# %%
anova(porscheLm)
# Out:
#            Df Sum Sq    Mean Sq     F value   Pr(>F)
# pj$Mileage  1 10733.814 10733.81372 127.52332 3.623003e-16
# pj$Porsche  1  4834.827  4834.82716  57.44028 3.448925e-10
# Residuals  57  4797.768    84.17138        NA           NA
